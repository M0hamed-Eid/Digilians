# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("apple_products_dataset_100k.csv")
df.head()
# Out:
#   product_id category model_name  release_year    price  rating       color  \
# 0    P000001     iMac  Model-754          2019  1519.71     4.6  Space Gray
# 1    P000002  AirPods  Model-214          2019  1124.86     3.5         Red
# 2    P000003  MacBook  Model-125          2016  1877.50     2.9      Silver
# 3    P000004  AirPods  Model-859          2019  1475.74     2.1      Silver
# 4    P000005  AirPods  Model-381          2017  3108.82     3.4        Blue
#
#   storage   ram         cpu           gpu screen_size  battery_mAh  \
# 0   256GB   4GB  A16 Bionic  M-Series GPU        6.7"         6181
# 1     1TB   4GB  A14 Bionic  M-Series GPU        6.1"         8085
# 2     1TB  16GB  A15 Bionic  M-Series GPU        5.4"         6359
# 3   512GB   8GB  A15 Bionic    Integrated         16"         4857
# 4   512GB   4GB  A15 Bionic     Apple GPU       13.3"        10785
#
#    weight_grams dimensions_mm  warranty country_origin seller_id  in_stock  \
# ...

# %%
df.tail()
# Out:
#       product_id     category model_name  release_year    price  rating  \
# 99995    P099996  Apple Watch  Model-409          2017  1215.27     5.0
# 99996    P099997      AirPods  Model-701          2015   887.88     3.0
# 99997    P099998         iMac  Model-571          2015  2303.21     4.6
# 99998    P099999       iPhone  Model-951          2019  1166.86     3.2
# 99999    P100000         iMac  Model-400          2017  2149.45     4.7
#
#             color storage   ram         cpu         gpu screen_size  \
# 99995  Space Gray    32GB   8GB          M3  Integrated        6.1"
# 99996        Blue   512GB  32GB          M3   Apple GPU         16"
# 99997  Space Gray     1TB   8GB          M2   Apple GPU       13.3"
# 99998       White   128GB  16GB  A16 Bionic   Apple GPU        6.7"
# 99999        Gold     1TB   6GB  A16 Bionic   Apple GPU       10.2"
#
#        battery_mAh  weight_grams dimensions_mm  warranty country_origin  \
# ...

# %%
df.describe()
# Out:
#         release_year          price         rating    battery_mAh  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean     2019.487210    1902.278098       2.997510    6768.332740
# std         2.875465     925.079772       1.156889    3033.377945
# min      2015.000000     300.030000       1.000000    1500.000000
# 25%      2017.000000    1098.507500       2.000000    4135.000000
# 50%      2019.000000    1903.405000       3.000000    6779.000000
# 75%      2022.000000    2704.225000       4.000000    9397.000000
# max      2024.000000    3499.950000       5.000000   11999.000000
#
#         weight_grams   review_count
# count  100000.000000  100000.000000
# mean     1598.315840    2500.821250
# std       807.638303    1441.585681
# min       200.000000       0.000000
# 25%       898.000000    1253.000000
# 50%      1597.000000    2499.000000
# 75%      2299.000000    3747.000000
# max      2999.000000    4999.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   product_id      100000 non-null  object
#  1   category        100000 non-null  object
#  2   model_name      100000 non-null  object
#  3   release_year    100000 non-null  int64
#  4   price           100000 non-null  float64
#  5   rating          100000 non-null  float64
#  6   color           100000 non-null  object
#  7   storage         100000 non-null  object
#  8   ram             100000 non-null  object
#  9   cpu             100000 non-null  object
#  10  gpu             100000 non-null  object
#  11  screen_size     100000 non-null  object
#  12  battery_mAh     100000 non-null  int64
#  13  weight_grams    100000 non-null  int64
#  14  dimensions_mm   100000 non-null  object
#  15  warranty        100000 non-null  object
# ...

# %%
df.iloc[1:4, 3:5]
# Out:
#    release_year    price
# 1          2019  1124.86
# 2          2016  1877.50
# 3          2019  1475.74

# %%
df.loc[3:8]
# Out:
#   product_id category model_name  release_year    price  rating   color  \
# 3    P000004  AirPods  Model-859          2019  1475.74     2.1  Silver
# 4    P000005  AirPods  Model-381          2017  3108.82     3.4    Blue
# 5    P000006     iPad  Model-350          2021  1908.07     2.0     Red
# 6    P000007  MacBook  Model-328          2023  3460.40     1.5    Blue
# 7    P000008  MacBook  Model-242          2024  2767.65     4.6   White
# 8    P000009  MacBook  Model-854          2020   714.59     4.6    Blue
#
#   storage   ram         cpu         gpu screen_size  battery_mAh  \
# 3   512GB   8GB  A15 Bionic  Integrated         16"         4857
# 4   512GB   4GB  A15 Bionic   Apple GPU       13.3"        10785
# 5    32GB   8GB  A16 Bionic   Apple GPU         16"        10629
# 6    64GB   4GB  A14 Bionic   Apple GPU         16"         9241
# 7    64GB  16GB          M3   Apple GPU        5.4"         3284
# 8     2TB  16GB  A14 Bionic   Apple GPU         16"         4614
#
# ...

# %%
df["price"]
# Out:
# 0        1519.71
# 1        1124.86
# 2        1877.50
# 3        1475.74
# 4        3108.82
#           ...
# 99995    1215.27
# 99996     887.88
# 99997    2303.21
# 99998    1166.86
# 99999    2149.45
# Name: price, Length: 100000, dtype: float64

# %%
type(df["price"])
# Out:
# pandas.core.series.Series

# %%
df["price"] >2000
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 99995    False
# 99996    False
# 99997     True
# 99998    False
# 99999     True
# Name: price, Length: 100000, dtype: bool

# %%
type(df["price"] >2000)
# Out:
# pandas.core.series.Series

# %%
df[df["price"] >3499]

# %%
type(df[df["price"] >3499])
# Out:
# pandas.core.frame.DataFrame

# %%
df[df["price"] >3499][["price","category"]]
# Out:
#          price     category
# 718    3499.24       iPhone
# 6771   3499.24         iMac
# 9736   3499.95       iPhone
# 11721  3499.17      MacBook
# 13068  3499.61         iPad
# 15037  3499.88      AirPods
# 21277  3499.77         iMac
# 21998  3499.85         iPad
# 25643  3499.50  Apple Watch
# 30671  3499.22       iPhone
# 30801  3499.62         iPad
# 35853  3499.44  Apple Watch
# 36730  3499.51  Apple Watch
# 41297  3499.16      MacBook
# 43256  3499.87      AirPods
# 44645  3499.87       iPhone
# 45919  3499.20      AirPods
# 45985  3499.44         iMac
# 48643  3499.01      MacBook
# 49920  3499.74       iPhone
# 54812  3499.78         iMac
# 58199  3499.52         iMac
# 58251  3499.37      AirPods
# 58519  3499.36         iPad
# 65336  3499.57      AirPods
# 65718  3499.05         iMac
# 66486  3499.13       iPhone
# 68214  3499.69      AirPods
# 70987  3499.37       iPhone
# 71480  3499.28       iPhone
# 76757  3499.47         iMac
# 78587  3499.81  Apple Watch
# ...

# %%
df.loc[df["price"]>3499, ["category", "release_year"]]
# Out:
#           category  release_year
# 718         iPhone          2017
# 6771          iMac          2016
# 9736        iPhone          2024
# 11721      MacBook          2022
# 13068         iPad          2023
# 15037      AirPods          2019
# 21277         iMac          2019
# 21998         iPad          2019
# 25643  Apple Watch          2020
# 30671       iPhone          2023
# 30801         iPad          2016
# 35853  Apple Watch          2019
# 36730  Apple Watch          2022
# 41297      MacBook          2016
# 43256      AirPods          2022
# 44645       iPhone          2016
# 45919      AirPods          2024
# 45985         iMac          2019
# 48643      MacBook          2021
# 49920       iPhone          2023
# 54812         iMac          2019
# 58199         iMac          2015
# 58251      AirPods          2017
# 58519         iPad          2024
# 65336      AirPods          2024
# 65718         iMac          2019
# 66486       iPhone          2015
# ...

# %%
df[df["model_name"] == "Model-859"]
# Out:
#       product_id category model_name  release_year    price  rating  \
# 3        P000004  AirPods  Model-859          2019  1475.74     2.1
# 519      P000520     iPad  Model-859          2019  2038.47     3.9
# 649      P000650  MacBook  Model-859          2017  1338.33     2.0
# 1826     P001827  AirPods  Model-859          2021  1570.17     1.5
# 2091     P002092     iMac  Model-859          2024  1300.03     2.4
# ...          ...      ...        ...           ...      ...     ...
# 96864    P096865  MacBook  Model-859          2020  3395.77     4.3
# 96988    P096989  MacBook  Model-859          2017  1577.57     1.1
# 97409    P097410  AirPods  Model-859          2017  3305.63     1.0
# 99534    P099535     iMac  Model-859          2017  2294.78     3.9
# 99538    P099539  MacBook  Model-859          2021  1737.16     1.9
#
#             color storage   ram         cpu           gpu screen_size  \
# 3          Silver   512GB   8GB  A15 Bionic    Integrated         16"
# ...

# %%
df.groupby("rating")

# %%
df.groupby("rating", sort = True).sum()
# Out:
#                                                product_id  \
# rating
# 1.0     P000250P000255P000474P000728P000941P000945P001...
# 1.1     P000068P000210P000229P000271P000277P000288P000...
# 1.2     P000055P000103P000108P000146P000286P000396P000...
# 1.3     P000037P000046P000073P000077P000109P000190P000...
# 1.4     P000036P000057P000059P000118P000137P000141P000...
# 1.5     P000007P000091P000098P000223P000232P000234P000...
# 1.6     P000047P000099P000115P000196P000226P000302P000...
# 1.7     P000041P000102P000127P000203P000208P000251P000...
# 1.8     P000017P000071P000072P000182P000212P000297P000...
# 1.9     P000043P000044P000145P000153P000168P000224P000...
# 2.0     P000006P000016P000042P000100P000124P000184P000...
# 2.1     P000004P000074P000081P000090P000120P000174P000...
# 2.2     P000026P000133P000199P000215P000219P000231P000...
# 2.3     P000034P000048P000062P000083P000121P000204P000...
# 2.4     P000039P000049P000082P000086P000087P000157P000...
# ...

# %%
df[df["color"] == "Silver"][["release_year", "price", "country_origin"]]
# Out:
#        release_year    price country_origin
# 2              2016  1877.50          India
# 3              2019  1475.74            USA
# 12             2021   315.34          Japan
# 16             2024  1901.43             UK
# 28             2019  2404.75          India
# ...             ...      ...            ...
# 99927          2020  1849.83        Germany
# 99958          2016  2679.17          China
# 99972          2024  3143.80          China
# 99980          2021  1712.75        Germany
# 99987          2016  2160.07          Japan
#
# [14207 rows x 3 columns]

# %%
df.groupby("country_origin")["price"].sum()
# Out:
# country_origin
# China      31678547.89
# Germany    31811983.62
# India      31868593.56
# Japan      31885047.89
# UK         31171660.93
# USA        31811975.90
# Name: price, dtype: float64

# %%
df.groupby(["country_origin", "ram"])["price"].sum()
# Out:
# country_origin  ram
# China           16GB    6274287.01
#                 32GB    6489954.72
#                 4GB     6442376.22
#                 6GB     6216692.72
#                 8GB     6255237.22
# Germany         16GB    6331758.78
#                 32GB    6341549.23
#                 4GB     6337218.16
#                 6GB     6386520.91
#                 8GB     6414936.54
# India           16GB    6234381.66
#                 32GB    6495273.22
#                 4GB     6535414.81
#                 6GB     6326025.18
#                 8GB     6277498.69
# Japan           16GB    6435665.92
#                 32GB    6332787.64
#                 4GB     6426877.24
#                 6GB     6234849.82
#                 8GB     6454867.27
# UK              16GB    6295284.65
#                 32GB    5941868.69
#                 4GB     6286563.31
#                 6GB     6270398.60
#                 8GB     6377545.68
# USA             16GB    6632884.19
# ...

# %%
df.groupby(["country_origin","ram"]).agg({"price":["sum", "max", "min"], "weight_grams":["mean", "std"]})
# Out:
#                           price                  weight_grams
#                             sum      max     min         mean         std
# country_origin ram
# China          16GB  6274287.01  3499.74  300.23  1595.866404  809.194735
#                32GB  6489954.72  3499.88  303.12  1559.135828  799.088907
#                4GB   6442376.22  3499.05  300.07  1621.084352  814.547372
#                6GB   6216692.72  3498.31  300.28  1607.020120  814.148519
#                8GB   6255237.22  3498.73  300.19  1602.149618  814.240590
# Germany        16GB  6331758.78  3498.74  301.31  1612.591346  814.776407
#                32GB  6341549.23  3498.63  300.17  1620.881602  807.812555
#                4GB   6337218.16  3497.71  300.54  1621.980024  796.409815
#                6GB   6386520.91  3499.50  301.30  1598.142857  801.233362
#                8GB   6414936.54  3498.62  302.30  1591.251355  804.740984
# India          16GB  6234381.66  3499.87  300.68  1579.379705  810.990394
# ...
