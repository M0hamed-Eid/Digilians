# %%
import pandas as pd

# %%
df = pd.read_csv("dummy_data.csv")
df
# Out:
#    id          name                  email   age  country
# 0   1     Ahmed Ali      ahmed@example.com  25.0    Egypt
# 1   2  Sara Mohamed       sara@example.com  30.0    Egypt
# 2   3   Omar Hassan       omar@example.com  22.0    Egypt
# 3   4     Mona Adel       mona@example.com  28.0    Egypt
# 4   5  Youssef Samy    youssef@example.com  35.0    Egypt
# 5   6           Eid  mohammedeid@gmail.com   NaN  America

# %%
df = pd.read_csv("dummy_data.csv", usecols=["name", "email"])
df
# Out:
#            name                  email
# 0     Ahmed Ali      ahmed@example.com
# 1  Sara Mohamed       sara@example.com
# 2   Omar Hassan       omar@example.com
# 3     Mona Adel       mona@example.com
# 4  Youssef Samy    youssef@example.com
# 5           Eid  mohammedeid@gmail.com

# %%
df = pd.read_csv("dummy_data.csv", index_col="id")
df
# Out:
#             name                  email   age  country
# id
# 1      Ahmed Ali      ahmed@example.com  25.0    Egypt
# 2   Sara Mohamed       sara@example.com  30.0    Egypt
# 3    Omar Hassan       omar@example.com  22.0    Egypt
# 4      Mona Adel       mona@example.com  28.0    Egypt
# 5   Youssef Samy    youssef@example.com  35.0    Egypt
# 6            Eid  mohammedeid@gmail.com   NaN  America

# %%
df = pd.read_csv("dummy_data.csv", na_values=["N/A", "unknwon"])
df
# Out:
#    id          name                  email   age  country
# 0   1     Ahmed Ali      ahmed@example.com  25.0    Egypt
# 1   2  Sara Mohamed       sara@example.com  30.0    Egypt
# 2   3   Omar Hassan       omar@example.com  22.0    Egypt
# 3   4     Mona Adel       mona@example.com  28.0    Egypt
# 4   5  Youssef Samy    youssef@example.com  35.0    Egypt
# 5   6           Eid  mohammedeid@gmail.com   NaN  America

# %%
scores = {"Name": ['a','b','c','d','e'],"score": [195,56,42,41,72]}

df = pd.DataFrame(scores)
df
# Out:
#   Name  score
# 0    a    195
# 1    b     56
# 2    c     42
# 3    d     41
# 4    e     72

# %%
df1 = df.to_csv("my name.csv")
df1 = pd.read_csv("my name.csv")
df1
# Out:
#    Unnamed: 0 Name  score
# 0           0    a    195
# 1           1    b     56
# 2           2    c     42
# 3           3    d     41
# 4           4    e     72

# %%
df1 = df.to_csv("my name.csv", index = False)
df1 = pd.read_csv("my name.csv")
df1
# Out:
#   Name  score
# 0    a    195
# 1    b     56
# 2    c     42
# 3    d     41
# 4    e     72

# %%
df2 = df1.loc[1:3]
df2
# Out:
#   Name  score
# 1    b     56
# 2    c     42
# 3    d     41

# %%
df2 = df1.iloc[0:2, 1]
df2
# Out:
# 0    195
# 1     56
# Name: score, dtype: int64

# %%
df2 = df1.iloc[2, 1]
df2
# Out:
# np.int64(42)
