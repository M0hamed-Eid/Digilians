# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("covid.csv")
df
# Out:
#             Country/Region      Continent    Population  TotalCases  NewCases  \
# 0                      USA  North America  3.311981e+08     5032179       NaN
# 1                   Brazil  South America  2.127107e+08     2917562       NaN
# 2                    India           Asia  1.381345e+09     2025409       NaN
# 3                   Russia         Europe  1.459409e+08      871894       NaN
# 4             South Africa         Africa  5.938157e+07      538184       NaN
# ..                     ...            ...           ...         ...       ...
# 204             Montserrat  North America  4.992000e+03          13       NaN
# 205  Caribbean Netherlands  North America  2.624700e+04          13       NaN
# 206       Falkland Islands  South America  3.489000e+03          13       NaN
# 207           Vatican City         Europe  8.010000e+02          12       NaN
# 208         Western Sahara         Africa  5.986820e+05          10       NaN
#
# ...

# %%
df.head()
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       NaN
# 1         Brazil  South America  2.127107e+08     2917562       NaN
# 2          India           Asia  1.381345e+09     2025409       NaN
# 3         Russia         Europe  1.459409e+08      871894       NaN
# 4   South Africa         Africa  5.938157e+07      538184       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
# 2      41638.0        NaN       1377384.0           NaN     606387.0
# 3      14606.0        NaN        676357.0           NaN     180931.0
# 4       9604.0        NaN        387316.0           NaN     141264.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# ...

# %%
df.tail()
# Out:
#             Country/Region      Continent  Population  TotalCases  NewCases  \
# 204             Montserrat  North America      4992.0          13       NaN
# 205  Caribbean Netherlands  North America     26247.0          13       NaN
# 206       Falkland Islands  South America      3489.0          13       NaN
# 207           Vatican City         Europe       801.0          12       NaN
# 208         Western Sahara         Africa    598682.0          10       NaN
#
#      TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 204          1.0        NaN            10.0           NaN          2.0
# 205          NaN        NaN             7.0           NaN          6.0
# 206          NaN        NaN            13.0           NaN          0.0
# 207          NaN        NaN            12.0           NaN          0.0
# 208          1.0        NaN             8.0           NaN          1.0
#
#      Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country/Region    209 non-null    object
#  1   Continent         208 non-null    object
#  2   Population        208 non-null    float64
#  3   TotalCases        209 non-null    int64
#  4   NewCases          4 non-null      float64
#  5   TotalDeaths       188 non-null    float64
#  6   NewDeaths         3 non-null      float64
#  7   TotalRecovered    205 non-null    float64
#  8   NewRecovered      3 non-null      float64
#  9   ActiveCases       205 non-null    float64
#  10  Serious,Critical  122 non-null    float64
#  11  Tot Cases/1M pop  208 non-null    float64
#  12  Deaths/1M pop     187 non-null    float64
#  13  TotalTests        191 non-null    float64
#  14  Tests/1M pop      191 non-null    float64
#  15  WHO Region        184 non-null    object
# ...

# %%
df.describe()
# Out:
#          Population    TotalCases     NewCases    TotalDeaths   NewDeaths  \
# count  2.080000e+02  2.090000e+02     4.000000     188.000000    3.000000
# mean   3.041549e+07  9.171850e+04  1980.500000    3792.590426  300.000000
# std    1.047661e+08  4.325867e+05  3129.611424   15487.184877  451.199512
# min    8.010000e+02  1.000000e+01    20.000000       1.000000    1.000000
# 25%    9.663140e+05  7.120000e+02    27.500000      22.000000   40.500000
# 50%    7.041972e+06  4.491000e+03   656.000000     113.000000   80.000000
# 75%    2.575614e+07  3.689600e+04  2609.000000     786.000000  449.500000
# max    1.381345e+09  5.032179e+06  6590.000000  162804.000000  819.000000
#
#        TotalRecovered  NewRecovered   ActiveCases  Serious,Critical  \
# count    2.050000e+02      3.000000  2.050000e+02        122.000000
# mean     5.887898e+04   1706.000000  2.766433e+04        534.393443
# std      2.566984e+05   2154.779803  1.746327e+05       2047.518613
# ...

# %%
df.describe(include="O")
# Out:
#        Country/Region Continent WHO Region iso_alpha
# count             209       208        184       209
# unique            209         6          6       193
# top               USA    Africa     Europe
# freq                1        57         55        10

# %%
df.columns
# Out:
# Index(['Country/Region', 'Continent', 'Population', 'TotalCases', 'NewCases',
#        'TotalDeaths', 'NewDeaths', 'TotalRecovered', 'NewRecovered',
#        'ActiveCases', 'Serious,Critical', 'Tot Cases/1M pop', 'Deaths/1M pop',
#        'TotalTests', 'Tests/1M pop', 'WHO Region', 'iso_alpha'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Country/Region        0
# Continent             1
# Population            1
# TotalCases            0
# NewCases            205
# TotalDeaths          21
# NewDeaths           206
# TotalRecovered        4
# NewRecovered        206
# ActiveCases           4
# Serious,Critical     87
# Tot Cases/1M pop      1
# Deaths/1M pop        22
# TotalTests           18
# Tests/1M pop         18
# WHO Region           25
# iso_alpha             0
# dtype: int64

# %%
df['Population'] = df['Population'].fillna(df['Population'].median())

# %%
df['Continent'] = df['Continent'].fillna(df['Continent'].mode()[0])

# %%
df['WHO Region'] = df['WHO Region'].fillna(df['WHO Region'].mode()[0])

# %%
df['TotalDeaths'] = df['TotalDeaths'].fillna(df['TotalDeaths'].median())

# %%
df['TotalRecovered'] = df['TotalRecovered'].fillna(df['TotalRecovered'].median())

# %%
df['ActiveCases'] = df['ActiveCases'].fillna(df['ActiveCases'].median())

# %%
df['Serious,Critical'] = df['Serious,Critical'].fillna(df['Serious,Critical'].median())

# %%
df['Tot Cases/1M pop'] = df['Tot Cases/1M pop'].fillna(df['Tot Cases/1M pop'].median())

# %%
df['Deaths/1M pop'] = df['Deaths/1M pop'].fillna(df['Deaths/1M pop'].median())

# %%
df['TotalTests'] = df['TotalTests'].fillna(df['TotalTests'].median())

# %%
df['Tests/1M pop'] = df['Tests/1M pop'].fillna(df['Tests/1M pop'].median())

# %%
# For 'NewCases', 'NewDeaths', 'NewRecovered', we can fill these with 0 for simplicity
df['NewCases'] = df['NewCases'].fillna(0)
df['NewDeaths'] = df['NewDeaths'].fillna(0)
df['NewRecovered'] = df['NewRecovered'].fillna(0)

# %%
# Step 2: Drop columns with excessive missing data if necessary
# Here, we drop 'Serious,Critical' as it has 87 missing values, which is too high.
df.drop(columns=['Serious,Critical'], inplace=True)

# %%
# One-Hot Encoding for categorical columns like 'Continent', 'WHO Region', etc.
df = pd.get_dummies(df, columns=['Continent', 'WHO Region'], drop_first=True)

# %%
df.isnull().sum()
# Out:
# Country/Region                     0
# Population                         0
# TotalCases                         0
# NewCases                           0
# TotalDeaths                        0
# NewDeaths                          0
# TotalRecovered                     0
# NewRecovered                       0
# ActiveCases                        0
# Tot Cases/1M pop                   0
# Deaths/1M pop                      0
# TotalTests                         0
# Tests/1M pop                       0
# iso_alpha                          0
# Continent_Asia                     0
# Continent_Australia/Oceania        0
# Continent_Europe                   0
# Continent_North America            0
# Continent_South America            0
# WHO Region_Americas                0
# WHO Region_EasternMediterranean    0
# WHO Region_Europe                  0
# WHO Region_South-EastAsia          0
# WHO Region_WesternPacific          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country/Region                   209 non-null    object
#  1   Population                       209 non-null    float64
#  2   TotalCases                       209 non-null    int64
#  3   NewCases                         209 non-null    float64
#  4   TotalDeaths                      209 non-null    float64
#  5   NewDeaths                        209 non-null    float64
#  6   TotalRecovered                   209 non-null    float64
#  7   NewRecovered                     209 non-null    float64
#  8   ActiveCases                      209 non-null    float64
#  9   Tot Cases/1M pop                 209 non-null    float64
#  10  Deaths/1M pop                    209 non-null    float64
#  11  TotalTests                       209 non-null    float64
# ...
