# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
m=100
X = 6*np.random.rand(m,1)-3

# %%
y = 0.5* X**2 + X + 2 + np.random.randn(m,1)
y.shape
# Out:
# (100, 1)

# %%
plt.scatter(X,y)

# %%
X.min()
# Out:
# np.float64(-2.8823664803893605)

# %%
X.max()
# Out:
# np.float64(2.993868283429002)

# %%
X.shape
# Out:
# (100, 1)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_features = PolynomialFeatures(degree=3, include_bias=True)
X_poly = poly_features.fit_transform(X)

# %%
X[0]
# Out:
# array([1.04638131])

# %%
X_poly[0]
# Out:
# array([1.        , 1.04638131, 1.09491385, 1.14569739])

# %%
(-1.72064653)**2
# Out:
# 2.960624481201041

# %%
X_poly.shape
# Out:
# (100, 4)

# %%
X.shape
# Out:
# (100, 1)

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X_poly,y)#training
# Out:
# LinearRegression()

# %%
lin_reg.intercept_
# Out:
# array([1.64868319])

# %%
lin_reg.coef_
# Out:
# array([[0.        , 0.94635297, 0.572579  , 0.02361257]])

# %%
y = 0.5* X**2 + X + 2 + np.random.randn(m,1)

# %%
#add, sub
x1=input()
x2=input()
op=input()
if op=='add'
result=x1+x2
# Out:
#   Cell In[63], line 5
#     if op=='add'
#                 ^
# SyntaxError: expected ':'
